# %% [markdown]
# <a href="https://colab.research.google.com/github/pdrobny/Potential_Talents/blob/main/P3_groq_github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install groq
# Out:
# Requirement already satisfied: groq in /usr/local/lib/python3.11/dist-packages (0.26.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from groq) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from groq) (2.11.5)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.11/dist-packages (from groq) (4.14.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->groq) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (0.4.1)

# %%
import pandas as pd
import numpy as np
import warnings
import logging
import random
import requests
import sys
import re
from groq import Groq
warnings.filterwarnings('ignore', category=UserWarning)

# %%
df = pd.read_csv('talents.csv')
df
# Out:
#        id                                              title  \
# 0       1  innovative and driven professional seeking a r...
# 1     431  aspiring data science professional focused on ...
# 2     544  data analyst data scientist business analyst d...
# 3     833  data analyst turning complex data into actiona...
# 4     199  ms in information systems northeastern univers...
# ...   ...                                                ...
# 1260  648  research specialist university of rochester di...
# 1261  730            medical biller at brick pediatric group
# 1262  990                                 ingeniero elctrico
# 1263  296          company owner at armstrong cleans carpets
# 1264  551  python arcpy arcgis pro esri products geoai do...
#
#       sentence_bert_cossim
# 0                 1.000000
# 1                 0.769162
# 2                 0.768222
# 3                 0.745245
# 4                 0.727268
# ...                    ...
# 1260              0.079923
# 1261              0.072848
# 1262              0.067254
# 1263              0.056890
# 1264              0.024555
#
# [1265 rows x 3 columns]

# %%
# Get a sample of available job titles to reduce prompt size
# You can adjust the sample size (e.g., 100 or 200) based on testing to stay within the token limit
sample_size = 200
sample_candidates = df['title'].sample(min(sample_size, len(df))).tolist()

# %%
# Initialize Groq LLM (replace with actual API call)
client= Groq(api_key="<api key>")

# %%
search_term = "ML Engineer"

# %%
# Construct prompt
prompt = f"""
Rank the top 5 most similar job titles to "{search_term}" based on relevance.
Available job titles: {sample_candidates}
Provide the results in a numbered list 1 to 5 with 1 being the most relevant. Do not explain.
"""

# Call Groq API
response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
        {"role": "system", "content": "You are an AI that ONLY outputs a list of top 5 job titles in strict numbered format. Do NOT explain, think, or reason."},
        {"role": "user", "content": prompt}
    ]
)

# Extract ranked job titles
top_5_jobs = response.choices[0].message.content.split("\n")[:5]

#print(top_5_jobs)
top_5_jobs
# Out:
# ['1. Data Scientist Machine Learning AI Expert Driving Data-Driven Financial Insights',
#  '2. Data Scientist Machine Learning AI Expert',
#  '3. Machine Learning Engineer',
#  '4. Data Scientist Analyst',
#  '5. ML Engineer']

# %%
# Construct prompt
# Construct strict output prompt
prompt = f"""
Available job titles:
{sample_candidates}

Search term: {search_term}

Return ONLY the top 5 most relevant job titles based on the search term.
Respond in this exact format:

1. <job title>
2. <job title>
3. <job title>
4. <job title>
5. <job title>
"""



# Call Groq API
response = client.chat.completions.create(
    model="deepseek-r1-distill-llama-70b",
    messages=[
        {"role": "system", "content": "You are an AI that ONLY outputs a list of top 5 job titles in strict numbered format. Do NOT explain, think, or reason."},
        {"role": "user", "content": prompt}
    ]
)


# Extract ranked job titles
output = response.choices[0].message.content.strip().split("\n")
top_5_jobs = [line for line in output if re.match(r"^\d\.\s", line)][:5]

for job in top_5_jobs:
    print(job)
# Out:
# 1. machine learning engineer at cedar gate technologies ex- darazian daraz nepal alibaba group
# 2. m.s. computer science graduate machine learning data science enthusiast experienced in sap erp pythontensorflow pytorch aws gpa 3.74 san jose state university
# 3. machine learningdata scienceai researchcomputer vision machine perceptionnlp llms genai
# 4. machine learning engineer arizona state university masters robotics and autonomous systems in ai actively seeking full-time opportunities.
# 5. machine learning engineer 2
